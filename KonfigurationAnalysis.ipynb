# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d

# %%
dataPath = "Konfigurationen.CSV"

data = pd.read_csv(dataPath)
data = data.dropna()
#data = data.drop('case-fan')
print(data.head())
# Out:
#    price  cpu  video-card  motherboard   ram   psu  storage  case  cooler
# 0    100   15          25           20  10.0  30.0     15.0   5.0     0.0
# 1    200   35          55           30  15.0  35.0     20.0  10.0     0.0
# 2    300   60          80           40  25.0  40.0     35.0  20.0     0.0
# 3    400   80         150           40  30.0  40.0     40.0  20.0     0.0
# 4    500   90         195           60  40.0  45.0     40.0  30.0     0.0

# %%
x = data['price']

plt.plot(x, data['video-card'], color='orange', label='gpu')
plt.plot(x, data['cpu'], color='dodgerblue', label='cpu')
plt.plot(x, data['motherboard'], color='red', label='mb')
plt.plot(x, data['ram'], color='limegreen', label='ram')
plt.plot(x, data['psu'], color='violet', label='psu')
plt.plot(x, data['storage'], color='yellow', label='storage')
plt.plot(x, data['case'], color='cyan', label='case')
plt.plot(x, data['cooler'], color='black', label='cooler')
plt.title('Configurations: Component-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('Component-Price ')
plt.legend()
plt.savefig('KonfigurationPriceDevelopmet.png', dpi=300)
plt.show()

# %%
X = data['price'].values.reshape(-1, 1)
y = data['cpu']

model = LinearRegression()

model.fit(X,y)

cpuPrediction = model.predict(X)
functionsDict = {}
functionsDict['cpu'] = [model.coef_[0].round(2), model.intercept_.round(2)]
plt.scatter(X, y, label='original data')
plt.plot(X, cpuPrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: CPU Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('CPU Price')
plt.legend()
plt.savefig('cpuKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['video-card']

model = LinearRegression()

model.fit(X,y)

gpuPrediction = model.predict(X)
functionsDict['gpu'] = [model.coef_[0].round(2), model.intercept_.round(2)]

plt.scatter(X, y, label='original data')
plt.plot(X, gpuPrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: GPU-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('GPU Price')
plt.legend()
plt.savefig('gpuKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['motherboard']

model = LinearRegression()

model.fit(X,y)

mbPrediction = model.predict(X)
functionsDict['mb'] = [model.coef_[0].round(2), model.intercept_.round(2)]

plt.scatter(X, y, label='original data')
plt.plot(X, mbPrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: MB-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('MB Price')
plt.legend()
plt.savefig('mbKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['ram']

model = LinearRegression()

model.fit(X,y)

ramPrediction = model.predict(X)
functionsDict['ram'] = [model.coef_[0].round(2), model.intercept_.round(2)]

plt.scatter(X, y, label='original data')
plt.plot(X, ramPrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: RAM-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('RAM Price')
plt.legend()
plt.savefig('ramKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['psu']

model = LinearRegression()

model.fit(X,y)

psuPrediction = model.predict(X)
functionsDict['psu'] = [model.coef_[0].round(2), model.intercept_.round(2)]

plt.scatter(X, y, label='original data')
plt.plot(X, psuPrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: PSU-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('PSU Price')
plt.legend()
plt.savefig('psuKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['storage']

model = LinearRegression()

model.fit(X,y)

storagePrediction = model.predict(X)
functionsDict['storage'] = [model.coef_[0].round(2), model.intercept_.round(2)]

plt.scatter(X, y, label='original data')
plt.plot(X, storagePrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: Storage-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('Storage Price')
plt.legend()
plt.savefig('storageKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['case']

model = LinearRegression()

model.fit(X,y)

casePrediction = model.predict(X)
functionsDict['case'] = [model.coef_[0].round(2), model.intercept_.round(2)]

plt.scatter(X, y, label='original data')
plt.plot(X, casePrediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.grid(visible=True)
plt.title('Linear Regression: Case-Price vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('Case Price')
plt.legend()
plt.savefig('caseKonfigurationPrice.png', dpi=300)
plt.show()

# %%
y = data['cooler']

interpolation = interp1d(x, y, kind='cubic', fill_value='extrapolate')
x_interp = np.linspace(min(x), max(x), 1000)
y_interp = interpolation(x_interp)


# Defining logistical function
def logistic_growth(x, L, k, x0):
    return L / (1 + np.exp(-k * (x - x0)))

def smooth_sigmoid(x, L, k, x0):
    return L * np.tanh(k * (x - x0))

initialGuess = (max(y_interp), 1, np.mean(x_interp))
# Perform curve fit
params, covariance = curve_fit(logistic_growth, x, y, p0=(initialGuess))

# Get fitted parameters
L, k, x0 = params
print(params)

# Generate points for the fitted curve
x_fit = np.linspace(min(x), max(x), 1000)
y_fit = logistic_growth(x_fit, L, k, x0)

plt.scatter(x, y, label='Original data')
plt.plot(x_interp, y_interp, label='Interpolation')
plt.plot(x_fit, y_fit, color='red', label=f'Logistic Growth Fit\nL={L:.2f}, k={k:.2f}, x0={x0:.2f}')
plt.title('Logistic Growth Model')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# [ 83.05555558   1.00296681 951.36825137]
# c:\Users\janik\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\janik\AppData\Local\Temp\ipykernel_20392\1431317179.py:10: RuntimeWarning: overflow encountered in exp
#   return L / (1 + np.exp(-k * (x - x0)))

# %% [markdown]
# ### Checking model accuracy
# The configurations were designed in a way such that at any price point sum of the cost of all the components would not exceed specific price point. Now adding up each each regression should ideally result in a function resembling m = 1, n = 0.

# %%
varifyPrediction = cpuPrediction + gpuPrediction + mbPrediction + ramPrediction + storagePrediction + psuPrediction + casePrediction
m = (varifyPrediction[2] - varifyPrediction[1]) / (300 - 200) 
n = varifyPrediction[1] - m * 200
functionsDict['overall'] = [m.round(2), n.round(2)]

plt.plot(X, varifyPrediction, color='red', label=f"""m = {str(m.round(2))} \n n = {str(n.round(2))}""")
plt.grid(visible=True)
plt.title('Linear Regression: Sum of All Prices vs Configuration-Price')
plt.xlabel('Configuration Price')
plt.ylabel('Predicted Price')
plt.legend()
plt.savefig('varifyKonfigurationPrice.png', dpi=300)
plt.show()

# %%
with open('functions.json', 'w') as file:
    file.write('[{')
    for key in functionsDict:
        if key != "overall":
            file.write(f'"{key}":[{functionsDict[key][0]},{functionsDict[key][1]}],')
        else:
            file.write(f'"{key}":[{functionsDict[key][0]},{functionsDict[key][1]}]')
    file.write('}]')
