# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
cpuPath = "./data-staging/cpu.json"
cpuData = pd.read_json(cpuPath)

# Removing all rows where price is null
cpuData.dropna(subset=['price'], inplace=True)

plt.scatter(cpuData['core_count'], cpuData['price'])
plt.show()

# %%
X = cpuData['core_count'].values.reshape(-1, 1)
y = cpuData['price']

model = LinearRegression()

model.fit(X,y)

prediction = model.predict(X)

plt.scatter(X, y, label='original data')
plt.plot(X, prediction, color='red', label=f"""m = {model.coef_[0].round(2)} \n n = {model.intercept_.round(2)}""")
plt.title('Linear Regression: Cores vs Price')
plt.xlabel('Number of Cores')
plt.ylabel('Price')
plt.legend()
plt.savefig('cpu.png', dpi=300)
plt.show()
